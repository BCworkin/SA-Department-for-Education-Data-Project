# %%
from pyspark.sql import functions

df_attendance = spark.read.csv(
    "/Volumes/workspace/default/raw/attendance_*.csv",
    header=True,
    inferSchema=True
)

df_enrolments = spark.read.csv(
    "/Volumes/workspace/default/raw/enrolments.csv",
    header=True,
    inferSchema=True
)
df_attendance.printSchema()
df_enrolments.printSchema()
